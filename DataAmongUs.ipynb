# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = 'data_among_form.csv'

form = pd.read_csv(path)

# %%
display(form)
# Out:
#                      Timestamp          lightswitch  \
# 0    2024/10/17 2:09:28 pm CET  Clicky light switch
# 1    2024/10/17 2:09:29 pm CET  Clicky light switch
# 2    2024/10/17 2:10:19 pm CET  Twisty light switch
# 3    2024/10/17 2:12:30 pm CET  Clicky light switch
# 4    2024/10/17 2:15:32 pm CET  Clicky light switch
# 5    2024/10/17 2:56:09 pm CET  Twisty light switch
# 6    2024/10/17 3:48:38 pm CET  Twisty light switch
# 7    2024/10/17 4:03:23 pm CET  Twisty light switch
# 8    2024/10/17 4:04:04 pm CET  Clicky light switch
# 9    2024/10/17 5:02:41 pm CET  Clicky light switch
# 10   2024/10/20 2:56:15 pm CET  Clicky light switch
# 11   2024/10/21 9:35:27 am CET  Twisty light switch
# 12  2024/10/22 10:05:12 am CET  Clicky light switch
# 13  2024/10/22 10:06:12 am CET                  NaN
# 14  2024/10/22 10:06:24 am CET  Clicky light switch
# 15  2024/10/22 10:07:47 am CET  Clicky light switch
# 16  2024/10/22 10:08:07 am CET  Clicky light switch
# 17  2024/10/22 10:08:25 am CET  Clicky light switch
#
#                                     Favorite_lucozade 20_mile_route  \
# 0                                           Raspberry     Paraglide
# 1                           I've never had a lucozade         Cycle
# 2                                     Caribbean Crush     Paraglide
# 3                                           Raspberry         Cycle
# 4                                     Caribbean Crush          Hike
# 5   I'm repulsed by the thought of lucozade why ar...     Paraglide
# 6                                         Blue Force      Paraglide
# 7                                           Raspberry         Cycle
# 8                                              Orange     Paraglide
# 9                           I've never had a lucozade     Paraglide
# 10                        not a fan of lucozade sport     Paraglide
# 11  I'm repulsed by the thought of lucozade why ar...         Cycle
# 12                          I've never had a lucozade         Cycle
# 13                                          Raspberry         Cycle
# 14  I'm repulsed by the thought of lucozade why ar...     Paraglide
# 15                                    Caribbean Crush          Hike
# 16                          I've never had a lucozade          Hike
# 17                                          Raspberry         Cycle
#
#    like_sweets Favorite_night_out   star_sign?      Would_rather  \
# 0          Yes           Festival  Sagittarius  Fingers for Toes
# 1           No         At home :(       Taurus  Fingers for Toes
# 2          Yes         At home :(    Capricorn  Fingers for Toes
# 3          Yes      Intimate Club     Aquarius  Fingers for Toes
# 4          Yes       Concert Hall        Libra  Fingers for Toes
# 5          Yes      Intimate Club  Sagittarius  Fingers for Toes
# 6          Yes         At home :(        Libra  Fingers for Toes
# 7          Yes       Concert Hall       Gemini  Fingers for Toes
# 8          Yes      Intimate Club       Gemini  Fingers for Toes
# 9          Yes         At home :(       Cancer  Fingers for Toes
# 10          No         At home :(        Libra               NaN
# 11          No         At home :(    Capricorn  Fingers for Toes
# 12         Yes       Concert Hall       Pisces  Toes for Fingers
# 13          No           Festival          Leo  Fingers for Toes
# 14         Yes       Concert Hall    Capricorn  Fingers for Toes
# 15         Yes       Concert Hall        Libra  Fingers for Toes
# 16         Yes      Intimate Club    Capricorn  Fingers for Toes
# 17          No         At home :(       Taurus  Toes for Fingers
#
#    favourite_colour
# 0            orange
# 1              Blue
# 2             Black
# 3         hot pink
# 4             Black
# 5             Lilac
# 6               Red
# 7            purple
# 8               RED
# 9              Blue
# 10  love all colors
# 11           Green
# 12             blue
# 13            green
# 14            White
# 15            Black
# 16             Blue
# 17              red

# %%
import numpy

# %%
form['like_sweets']
# Out:
# 0     Yes
# 1      No
# 2     Yes
# 3     Yes
# 4     Yes
# 5     Yes
# 6     Yes
# 7     Yes
# 8     Yes
# 9     Yes
# 10     No
# 11     No
# 12    Yes
# 13     No
# 14    Yes
# 15    Yes
# 16    Yes
# 17     No
# Name: like_sweets, dtype: object

# %%
form['Favorite_night_out']
# Out:
# 0          Festival
# 1        At home :(
# 2        At home :(
# 3     Intimate Club
# 4      Concert Hall
# 5     Intimate Club
# 6        At home :(
# 7      Concert Hall
# 8     Intimate Club
# 9        At home :(
# 10       At home :(
# 11       At home :(
# 12     Concert Hall
# 13         Festival
# 14     Concert Hall
# 15     Concert Hall
# 16    Intimate Club
# 17       At home :(
# Name: Favorite_night_out, dtype: object

# %%
#this sets up the figure size
plt.figure(figsize=(10, 6))

#this actually plots the graph

#Grabs the form variable, then selects the header we want to use (in this case lightswitch)
#It then counts how many times either clicky or twisty lightswitch appear
#Finally it plots a type 'bar' and give it a colour
form['lightswitch'].value_counts().plot(kind='bar', color='skyblue')

#gives it a title
plt.title('Light Switch Preference')
#give the X axis a name
plt.xlabel('Light Switch Type')
#give the Y axis a name
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
form['like_sweets'].value_counts().plot(kind='bar', color='skyblue')

#gives it a title
plt.title('like_sweets')
#give the X axis a name
plt.xlabel('Do you like s')
#give the Y axis a name
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
yes_sweets = form['like_sweets'].value_counts().get('Yes', 0)
no_sweets = form['like_sweets'].value_counts().get('No', 0)
print(yes_sweets, no_sweets)
# Out:
# 13 5

# %%
clicky_switch = form['lightswitch'].value_counts().get('Clicky light switch', 0)
twisty_switch = form['lightswitch'].value_counts().get('Twisty light switch', 0)
print(clicky_switch, twisty_switch)
# Out:
# 12 5

# %%
form['star_sign?'].value_counts().plot(kind='pie', color='skyblue')

#gives it a title
plt.title('Star Sign')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
form['Favorite_night_out'].value_counts().plot(kind='pie', color='skyblue')

#gives it a title
plt.title('Fav night out')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
from matplotlib_venn import venn3, venn2, venn3_circles
import scipy
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from matplotlib_venn import venn3, venn2, venn3_circles
#       2 import scipy
#       3 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib_venn'

# %%
like_sweets_yes = set(form[form['like_sweets'] == 'No'].index)
fav_night_out_at_home = set(form[form['Favorite_night_out'] == 'At home :('].index)

# Create the Venn diagram
plt.figure(figsize=(6, 6))
venn2([like_sweets_yes, fav_night_out_at_home], set_labels=('Hates Sweets', 'Favorite Night Out: At Home'))

# Add title
plt.title('Venn Diagram: Like Sweets vs Favorite Night Out At Home')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       4 # Create the Venn diagram
#       5 plt.figure(figsize=(6, 6))
# ----> 6 venn2([like_sweets_yes, fav_night_out_at_home], set_labels=('Hates Sweets', 'Favorite Night Out: At Home'))
#       8 # Add title
#       9 plt.title('Venn Diagram: Like Sweets vs Favorite Night Out At Home')
#
# NameError: name 'venn2' is not defined

# %%
like_sweets_no = set(form[form['like_sweets'] == 'No'].index)
likes_clicky = set(form[form['lightswitch'] == 'Twisty Light Switch'].index)


# Create the Venn diagram
plt.figure(figsize=(6, 6))
venn2([like_sweets_no, likes_clicky], set_labels=('Hates Sweets', 'Prefers Clicky Lightswiches'))

# Add title
plt.title('Doesnt like sweets and prefers clicky light switches')

# Show the plot
plt.show()

# %%
like_sweets_no = set(form[form['like_sweets'] == 'No'].index)
twentymiles_hike = set(form[form['20_mile_route'] == 'Hike'].index)
twentymiles_cycle = set(form[form['20_mile_route'] == 'Cycle'].index)


# Create the Venn diagram
plt.figure(figsize=(6, 6))
venn3([like_sweets_no, twentymiles_hike, twentymiles_cycle], set_labels=('Hates Sweets', 'Hikers', 'Cyclers'))

# Add title
plt.title('Doesnt like sweets and prefers clicky light switches')

# Show the plot
plt.show()

# %%
crosstab_data = pd.crosstab(index=[form['Favorite_night_out']],
                            columns=form['like_sweets'])

plt.figure(figsize=(10, 8))

sns.heatmap(crosstab_data, annot=True, fmt="d", cmap="YlGnBu")

# Add title and labels
plt.title('Heatmap of Nights Out vs Like Sweets')
plt.xlabel('Likes Sweets')
plt.ylabel('Night Out')

# Show the plot
plt.tight_layout()
plt.show()

# %%
crosstab_data = pd.crosstab(index=[form['20_mile_route']],
                            columns=form['like_sweets'])

plt.figure(figsize=(10, 8))

sns.heatmap(crosstab_data, annot=True, fmt="d", cmap="YlGnBu")

# Add title and labels
plt.title('Heatmap of Prefered way to traverse 20 miles vs Like Sweets')
plt.xlabel('Likes Sweets')
plt.ylabel('20-miles ')

# Show the plot
plt.tight_layout()
plt.show()

# %%
crosstab_data = pd.crosstab(index=[form['Favorite_night_out']],
                            columns=form['20_mile_route'])

plt.figure(figsize=(10, 8))

sns.heatmap(crosstab_data, annot=True, fmt="d", cmap="YlGnBu")

# Add title and labels
plt.title('Heatmap of Prefered way to traverse 20 miles vs Like Sweets')
plt.xlabel('Likes Sweets')
plt.ylabel('20-miles ')

# Show the plot
plt.tight_layout()
plt.show()
